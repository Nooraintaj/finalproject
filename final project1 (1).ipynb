# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
data=pd.read_csv("Customer Review.csv")
data
# Out:
#           ProductModelName ProductCategory  ProductPrice RetailerName  \
# 0        Samsung TV 60 LED              TV          1100      Walmart
# 1                Galaxy S4     Smart Phone           402         Frys
# 2     Samsung TV 65 Curved              TV          1899      Bestbuy
# 3                Surface 3          Tablet           999      Walmart
# 4        HP PAVALION  15.6          Laptop           299         Frys
# ...                    ...             ...           ...          ...
# 1995     Samsung TV 60 LED              TV          1100       Target
# 1996              iPhone 6     Smart Phone           589      Bestbuy
# 1997              iPad Air          Tablet           299      Walmart
# 1998             Surface 3          Tablet           925      Bestbuy
# 1999     Dell Ispiron 15.6          Laptop           349      Walmart
#
#       RetailerZip   RetailerCity RetailerState ProductOnSale ManufacturerName  \
# ...

# %%
data.columns
# Out:
# Index(['ProductModelName', 'ProductCategory', 'ProductPrice', 'RetailerName',
#        'RetailerZip', 'RetailerCity', 'RetailerState', 'ProductOnSale',
#        'ManufacturerName', 'ManufacturerRebate', 'UserID', 'UserAge',
#        'UserGender', 'UserOccupation', 'ReviewRating', 'ReviewDate',
#        'ReviewText'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ProductModelName      object
# ProductCategory       object
# ProductPrice           int64
# RetailerName          object
# RetailerZip            int64
# RetailerCity          object
# RetailerState         object
# ProductOnSale         object
# ManufacturerName      object
# ManufacturerRebate    object
# UserID                object
# UserAge                int64
# UserGender            object
# UserOccupation        object
# ReviewRating           int64
# ReviewDate            object
# ReviewText            object
# dtype: object

# %%
lambda i: print(data['ManufacturerName']) if data['ProductCategory']=="TV"
# Out:
#   File "<ipython-input-4-660a41b36a98>", line 1
#     lambda i: print(data['ManufacturerName']) if data['ProductCategory']=="TV"
#                                                                               ^
# SyntaxError: invalid syntax

# %%
data['ManufacturerName'].unique()
# Out:
# array(['Samsung', 'Microsoft', 'HP', 'Apple', 'Dell', 'LG'], dtype=object)

# %%
data.isna().sum()
# Out:
# ProductModelName      0
# ProductCategory       0
# ProductPrice          0
# RetailerName          0
# RetailerZip           0
# RetailerCity          0
# RetailerState         0
# ProductOnSale         0
# ManufacturerName      0
# ManufacturerRebate    0
# UserID                0
# UserAge               0
# UserGender            0
# UserOccupation        0
# ReviewRating          0
# ReviewDate            0
# ReviewText            0
# dtype: int64

# %%
cust_rating=data.groupby('ManufacturerName').ReviewRating.agg(['count','min','max']).sort_values('count', ascending=False)
cust_rating
# Out:
#                   count  min  max
# ManufacturerName
# Samsung             800    1    5
# Apple               400    1    5
# Dell                200    1    5
# HP                  200    1    5
# LG                  200    1    5
# Microsoft           200    1    5

# %%
cust_rating1=data.groupby('ProductModelName').ReviewRating.agg(['count','min','max']).sort_values('count', ascending=False)
cust_rating1
# Out:
#                       count  min  max
# ProductModelName
# Dell Ispiron 15.6       200    1    5
# Galaxy S4               200    1    5
# HP PAVALION  15.6       200    1    5
# LG 65                   200    1    5
# Samsung TV 60 LED       200    1    5
# Samsung TV 65 Curved    200    1    5
# Samsung Tab 4           200    1    5
# Surface 3               200    1    5
# iPad Air                200    1    5
# iPhone 6                200    1    5

# %%
review=data['ReviewText']
clean_text_1=[]

def to_lower(review):
    for words in review:
        clean_text_1.append(str.lower(words))

# %%
to_lower(review)

# %%
clean_text_1
# Out:
# ['great staff with the sale!! they did an extraordinary job and will be shopping there again! i love samsung!',
#  " really like this samsung galaxy 4. i don't use a  computer any more",
#  'the tv is great with superb picture quality.',
#  'its easy to carry and is more than a tablet its a laptop!',
#  'great laptop for the price. does everything you need for everyday computing.',
#  'i was expecting a tablet with limited function but i got a computer in the compact size of a tablet.',
#  'cpu overheats and dies after few hours of use',
#  "i don't like this lap top the bluetooth didn't work at all",
#  ' great computer for the price. excellent! very fast',
#  'amazing piece of technology.',
#  'i bought this phone for my mother. it was a tough for her to get a handle on working android but with my nieces help she can finally text. she seems very happy with it.',
#  'i like the surface pro 3 but not sure i like windows 8.1.',
#  ' i like everything...camera',
# ...

# %% [markdown]
# # TOKENIZING

# %%
clean_text_2=[]
from nltk.tokenize import sent_tokenize, word_tokenize

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sent_tok=[]
for sent in clean_text_1:
    sent=sent_tokenize(sent)
    sent_tok.append(sent)
sent_tok
# Out:
# [['great staff with the sale!!',
#   'they did an extraordinary job and will be shopping there again!',
#   'i love samsung!'],
#  [" really like this samsung galaxy 4. i don't use a  computer any more"],
#  ['the tv is great with superb picture quality.'],
#  ['its easy to carry and is more than a tablet its a laptop!'],
#  ['great laptop for the price.',
#   'does everything you need for everyday computing.'],
#  ['i was expecting a tablet with limited function but i got a computer in the compact size of a tablet.'],
#  ['cpu overheats and dies after few hours of use'],
#  ["i don't like this lap top the bluetooth didn't work at all"],
#  [' great computer for the price.', 'excellent!', 'very fast'],
#  ['amazing piece of technology.'],
#  ['i bought this phone for my mother.',
#   'it was a tough for her to get a handle on working android but with my nieces help she can finally text.',
#   'she seems very happy with it.'],
# ...

# %% [markdown]
# # WORD TOKENIZING

# %%
clean_text_2=[word_tokenize(i) for i in clean_text_1]
clean_text_2
# Out:
# [['great',
#   'staff',
#   'with',
#   'the',
#   'sale',
#   '!',
#   '!',
#   'they',
#   'did',
#   'an',
#   'extraordinary',
#   'job',
#   'and',
#   'will',
#   'be',
#   'shopping',
#   'there',
#   'again',
#   '!',
#   'i',
#   'love',
#   'samsung',
#   '!'],
#  ['really',
#   'like',
#   'this',
#   'samsung',
#   'galaxy',
#   '4.',
#   'i',
#   'do',
#   "n't",
#   'use',
#   'a',
#   'computer',
#   'any',
#   'more'],
#  ['the', 'tv', 'is', 'great', 'with', 'superb', 'picture', 'quality', '.'],
#  ['its',
#   'easy',
#   'to',
#   'carry',
#   'and',
#   'is',
#   'more',
#   'than',
#   'a',
#   'tablet',
#   'its',
#   'a',
#   'laptop',
#   '!'],
#  ['great',
#   'laptop',
#   'for',
#   'the',
#   'price',
#   '.',
#   'does',
#   'everything',
#   'you',
#   'need',
#   'for',
#   'everyday',
#   'computing',
#   '.'],
#  ['i',
#   'was',
#   'expecting',
#   'a',
#   'tablet',
#   'with',
#   'limited',
#   'function',
#   'but',
#   'i',
#   'got',
#   'a',
# ...

# %%
import re
clean_text_3=[]

for word in clean_text_2:
    clean=[]
    for w in word:
        res=re.sub(r'[^\w\s]','',w)
        if res != '':
            clean.append(res)
    clean_text_3.append(clean)
clean_text_3
# Out:
# [['great',
#   'staff',
#   'with',
#   'the',
#   'sale',
#   'they',
#   'did',
#   'an',
#   'extraordinary',
#   'job',
#   'and',
#   'will',
#   'be',
#   'shopping',
#   'there',
#   'again',
#   'i',
#   'love',
#   'samsung'],
#  ['really',
#   'like',
#   'this',
#   'samsung',
#   'galaxy',
#   '4',
#   'i',
#   'do',
#   'nt',
#   'use',
#   'a',
#   'computer',
#   'any',
#   'more'],
#  ['the', 'tv', 'is', 'great', 'with', 'superb', 'picture', 'quality'],
#  ['its',
#   'easy',
#   'to',
#   'carry',
#   'and',
#   'is',
#   'more',
#   'than',
#   'a',
#   'tablet',
#   'its',
#   'a',
#   'laptop'],
#  ['great',
#   'laptop',
#   'for',
#   'the',
#   'price',
#   'does',
#   'everything',
#   'you',
#   'need',
#   'for',
#   'everyday',
#   'computing'],
#  ['i',
#   'was',
#   'expecting',
#   'a',
#   'tablet',
#   'with',
#   'limited',
#   'function',
#   'but',
#   'i',
#   'got',
#   'a',
#   'computer',
#   'in',
#   'the',
#   'compact',
#   'size',
# ...

# %% [markdown]
# # STOP WORD REMOVAL

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
clean_text_4=[]
for words in clean_text_3:
    w=[]
    for word in words:
        if not word in stopwords.words('english'):
            w.append(word)
    clean_text_4.append(w)

# %%
clean_text_4
# Out:
# [['great',
#   'staff',
#   'sale',
#   'extraordinary',
#   'job',
#   'shopping',
#   'love',
#   'samsung'],
#  ['really', 'like', 'samsung', 'galaxy', '4', 'nt', 'use', 'computer'],
#  ['tv', 'great', 'superb', 'picture', 'quality'],
#  ['easy', 'carry', 'tablet', 'laptop'],
#  ['great', 'laptop', 'price', 'everything', 'need', 'everyday', 'computing'],
#  ['expecting',
#   'tablet',
#   'limited',
#   'function',
#   'got',
#   'computer',
#   'compact',
#   'size',
#   'tablet'],
#  ['cpu', 'overheats', 'dies', 'hours', 'use'],
#  ['nt', 'like', 'lap', 'top', 'bluetooth', 'nt', 'work'],
#  ['great', 'computer', 'price', 'excellent', 'fast'],
#  ['amazing', 'piece', 'technology'],
#  ['bought',
#   'phone',
#   'mother',
#   'tough',
#   'get',
#   'handle',
#   'working',
#   'android',
#   'nieces',
#   'help',
#   'finally',
#   'text',
#   'seems',
#   'happy'],
#  ['like', 'surface', 'pro', '3', 'sure', 'like', 'windows', '81'],
#  ['like', 'everything', 'camera'],
# ...

# %% [markdown]
# # STEMMING

# %%
#stemming converts the data into its root form
from nltk.stem.porter import PorterStemmer
port= PorterStemmer()

# %%
clean_text_5=[]
for words in clean_text_4:
    w=[]
    for word in words:
        w.append(word)
    clean_text_5.append(w)
clean_text_5
# Out:
# [['great',
#   'staff',
#   'sale',
#   'extraordinary',
#   'job',
#   'shopping',
#   'love',
#   'samsung'],
#  ['really', 'like', 'samsung', 'galaxy', '4', 'nt', 'use', 'computer'],
#  ['tv', 'great', 'superb', 'picture', 'quality'],
#  ['easy', 'carry', 'tablet', 'laptop'],
#  ['great', 'laptop', 'price', 'everything', 'need', 'everyday', 'computing'],
#  ['expecting',
#   'tablet',
#   'limited',
#   'function',
#   'got',
#   'computer',
#   'compact',
#   'size',
#   'tablet'],
#  ['cpu', 'overheats', 'dies', 'hours', 'use'],
#  ['nt', 'like', 'lap', 'top', 'bluetooth', 'nt', 'work'],
#  ['great', 'computer', 'price', 'excellent', 'fast'],
#  ['amazing', 'piece', 'technology'],
#  ['bought',
#   'phone',
#   'mother',
#   'tough',
#   'get',
#   'handle',
#   'working',
#   'android',
#   'nieces',
#   'help',
#   'finally',
#   'text',
#   'seems',
#   'happy'],
#  ['like', 'surface', 'pro', '3', 'sure', 'like', 'windows', '81'],
#  ['like', 'everything', 'camera'],
# ...

# %% [markdown]
# # LIMITIZING

# %%
from nltk.stem.wordnet import WordNetLemmatizer
wnet=WordNetLemmatizer()

# %%
import nltk 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lem=[]
for words in clean_text_4:
    w=[]
    for word in words:
        w.append(wnet.lemmatize(word))
    lem.append(w)
lem
# Out:
# [['great',
#   'staff',
#   'sale',
#   'extraordinary',
#   'job',
#   'shopping',
#   'love',
#   'samsung'],
#  ['really', 'like', 'samsung', 'galaxy', '4', 'nt', 'use', 'computer'],
#  ['tv', 'great', 'superb', 'picture', 'quality'],
#  ['easy', 'carry', 'tablet', 'laptop'],
#  ['great', 'laptop', 'price', 'everything', 'need', 'everyday', 'computing'],
#  ['expecting',
#   'tablet',
#   'limited',
#   'function',
#   'got',
#   'computer',
#   'compact',
#   'size',
#   'tablet'],
#  ['cpu', 'overheats', 'dy', 'hour', 'use'],
#  ['nt', 'like', 'lap', 'top', 'bluetooth', 'nt', 'work'],
#  ['great', 'computer', 'price', 'excellent', 'fast'],
#  ['amazing', 'piece', 'technology'],
#  ['bought',
#   'phone',
#   'mother',
#   'tough',
#   'get',
#   'handle',
#   'working',
#   'android',
#   'niece',
#   'help',
#   'finally',
#   'text',
#   'seems',
#   'happy'],
#  ['like', 'surface', 'pro', '3', 'sure', 'like', 'window', '81'],
#  ['like', 'everything', 'camera'],
# ...
